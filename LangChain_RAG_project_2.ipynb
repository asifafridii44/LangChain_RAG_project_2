# %%
# %pip install -qU  langchain-pinecone langchain-google-genai
from langchain_core.output_parsers import StrOutputParser
# Out:
#   WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProtocolError('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))': /packages/9b/4d/942198e2939efe7bfa484781590f082135e9931b8bcafb4bba62cf2d8f2f/aiohttp-3.10.11-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.5/41.5 kB 2.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 16.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 427.3/427.3 kB 17.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.5/87.5 kB 3.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.5/49.5 kB 2.2 MB/s eta 0:00:00

# %%
import os
from google.colab import userdata

#Setting up the Google Embedding model
from langchain_google_genai import GoogleGenerativeAIEmbeddings
os.environ["GOOGLE_API_KEY"] = userdata.get("GOOGLE_API_KEY")
embeddings = GoogleGenerativeAIEmbeddings(model="models/embedding-001")

# Setting up pine_cone model
from pinecone import Pinecone, ServerlessSpec
pinecone_api_key = userdata.get("PINECONE-API-KEY-2")

pc = Pinecone(api_key=pinecone_api_key)

# %%
import time

index_name = "rag-1"
index = pc.Index(index_name)

# %%
import os
from langchain_google_genai import GoogleGenerativeAIEmbeddings
os.environ["GOOGLE_API_KEY"] = userdata.get("GOOGLE_API_KEY")
embeddings = GoogleGenerativeAIEmbeddings(model="models/embedding-001")
vector = embeddings.embed_query("hello world")
print(len(vector))
vector[:5]
# Out:
# 768
# [0.04909781739115715,
#  -0.044328317046165466,
#  -0.025365281850099564,
#  -0.030721040442585945,
#  0.019068587571382523]

# %%
from langchain_pinecone import PineconeVectorStore

vector_store = PineconeVectorStore(index = index , embedding = embeddings)

# %%
# %pip install -qq docling docling-core python-dotenv
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.2/48.2 kB 3.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 113.3/113.3 kB 4.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.4/91.4 kB 6.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 52.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.0/66.0 kB 4.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 22.4/22.4 MB 46.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 54.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.1/42.1 kB 2.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 31.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 41.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 244.3/244.3 kB 17.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 472.8/472.8 kB 25.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 543.2/543.2 kB 30.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.3/47.3 kB 3.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 159.9/159.9 kB 10.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 422.9/422.9 kB 26.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 912.2/912.2 kB 42.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 286.8/286.8 kB 18.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 4.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 272.8/272.8 kB 17.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 8.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.4/119.4 kB 9.3 MB/s eta 0:00:00

# %%
# %pip install -q langchain requests pypdf langchain-community
from langchain.document_loaders import PyPDFLoader
import requests

url = "https://raw.githubusercontent.com/aliomershah/pdf-file-cv/main/cv-template.pdf"
filename = input("Enter name for your file : ")

response = requests.get(url)

with open(filename, 'wb') as f:
        f.write(response.content)
        print(f"PDF saved as {filename}")


loader = PyPDFLoader(filename)
documents = loader.load()

for doc in documents:
   print(doc.page_content)
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 298.0/298.0 kB 7.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 43.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.5/49.5 kB 3.7 MB/s eta 0:00:00

# %%
from langchain_core.documents import Document as LCDocument
from docling.document_converter import DocumentConverter
from uuid import uuid4


FILE_PATH = f"/content/{filename}"
dl_doc=DocumentConverter().convert(FILE_PATH).document
text = dl_doc.export_to_markdown()  #print the text in the following line to check the working
# print(text)

doc = [LCDocument(page_content=text, metadata={"source": FILE_PATH})]

vector1 = embeddings.embed_query(text)
id = [str(uuid4())]

vector_store.add_documents(documents=doc, ids=id)

# %% [markdown]
# Here we have invoked the LLM along with the uploaded document as a RAG system

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
llm  = ChatGoogleGenerativeAI(
    model = "gemini-2.0-flash-exp"
)

def answer_to_user(query :str):
  vector_results = vector_store.similarity_search_with_score(query, k=2)

  final_answer = llm.invoke(f"Answer this user query :{query}, Here are some reference to the answer {vector_results}, add from this {vector_results} as well.")
  return final_answer


answer = answer_to_user("Tell me about education")
answer.content

# %% [markdown]
# Here We have done the same thing but in chaining and a little bit of formatting as StrOutputParser and display markddown

# %%
from langchain_core.runnables import RunnablePassthrough
from langchain_core.prompts import ChatPromptTemplate
from IPython.display import Markdown



retriever = vector_store.as_retriever()


llm = ChatGoogleGenerativeAI(model="gemini-2.0-flash-exp")


template = """Answer this user query: {question}
Here's some information that might be helpful: {context}"""
prompt_template = ChatPromptTemplate.from_template(template)

rag_chain = (
    {"context": retriever, "question": RunnablePassthrough()}
    | prompt_template
    | llm
    | StrOutputParser()
)


query = "Tell me about surname "
display(Markdown(rag_chain.invoke(query)))
# Out:
# The provided document uses "SURNAME" as a placeholder for a person's last name within a CV template. It appears in the context of a full name: "Forename SURNAME".  The document doesn't provide any information about the history, origin, or meaning of surnames in general. It simply indicates where a surname should be placed within the context of a resume or CV.
